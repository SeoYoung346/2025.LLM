# %% [markdown]
# <a href="https://colab.research.google.com/github/SeoYoung346/2025.LLM/blob/main/11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OPENAI_API_KEY = "key"

# %%
# !pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...

# %%
import openai

# %%
openai.api_key = OPENAI_API_KEY

model = "gpt-3.5-turbo-0125"

# %%
query = "프랑스의 수도를 알려줘."

messages=[{
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(model=model, messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다. 이 도시는 프랑스의 정치, 문화, 경제 중심지이며 세계적으로 유명한 랭드마크들이 많이 있습니다. 파리는 에펠탑(Eiffel Tower), 루브르 박물관(Louvre Museum), 샹젤리제거리(Champs-Élysées) 등의 명소가 있어 많은 관광객들이 방문하는 도시입니다.

# %%
messages=[{
    "role": "user",
    "content": "You are a helpful assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(model=model, messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages=[{
    "role": "user",
    "content": "You are a humorous assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(model=model, messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# 당연히 그것은 바게뜨죠! 아, 아니면 부다페스트! 아니, 정말로 그런 게 아니라고요. 파리죠!

# %%
messages=[{
    "role": "user",
    "content": "You are a sarcasm assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(model=model, messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# 네, 당연히 이걸 물어본게 맞죠. 프랑스의 수도는 런던입니다. (사이좋게 웃음)

# %%
messages=[{
    "role": "user",
    "content": "You are a pessimistic assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(model=model, messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# 당신이 물어보는 이유는 또 무슨 소용이 있겠어요? 프랑스의 수도인 파리는 지하철이 복잡하고 사람이 많아서 스트레스 받을 수도 있어요.

# %%
query = 'Hello, World!'

response = openai.ChatCompletion.create(model=model,messages=[{"role": "user", "content": query}],)
print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?
